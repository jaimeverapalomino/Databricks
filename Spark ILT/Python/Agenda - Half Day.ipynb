# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 1200px">
# </div>

# %% [markdown]
# # Course Agenda
# ## Apache Spark™ Programming (Half-Day)

# %% [markdown]
# | Time | Topic &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; | Description &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; |
# |:----:|-------|-------------|
# | 10m  | **Introductions and Setup**| *Registration, Courseware & Q&As* |
# | 20m  | **[Apache Spark Overview]($./Apache Spark Overview)** | *About Databricks, Spark & Spark Architecture* |
# | 15m  | **[Databricks Environment]($./Other Topics/Databricks Environment)**| *DBFS, dbutils, Magic Commands: %run, %sh, %md, %fs* |
# | 25m  | **[Reading Data - CSV]($./Reading & Writing Data/DFRW 1 - CSV)** | *Spark Entry Point, Reading Data, Inferring Schemas, API Docs* |
# | 05m  | **[Writing Data]($./Reading & Writing Data/DFRW 9 - Writing Data)** | *Quick Intro to DataFrameWriters* |
# | 10m  | **Break** ||
# | 35m  | **[Intro To DataFrames, Part 1]($./Intro To DataFrames/Intro To DF Part 1)**  | *API Docs, DataFrames, cache(), show(), display(), limit(), count(), select(), drop(), distinct(), SQL, Temp Views* |
# | 25m  | **[Transformations And Actions]($./Other Topics/Transformations And Actions)** | *Lazy, Catalyst, Actions, Transformations, Wide vs. Narrow, Shuffling, Stages, Pipelining, Lineage* |
# | 30m  | **[Intro To DataFrames, Part 2]($./Intro To DataFrames/Intro To DF Part 2)** | *orderBy(), Column, filter(), first(), Row, collect(), take(n), Dataframe vs. DataSet* |
# | 10m  | **Additional Topics and Resources**||

# %% [markdown]
# General Notes:
# * The times indicated here *are approximate*
# * Actual times will vary by class size, class participation, and other unforeseen factors

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
