# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 1200px">
# </div>

# %% [markdown]
# # Partitioning Lab
# ## Exploring Partitions

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/wiki-book/general/logo_spark_tiny.png) Play Time
#
# Let's play around a little bit
# 0. Start with 8 partitions.
# 0. Run the code.
# 0. Open the **Spark UI**
# 0. Dig into the second job (remember the first is for the range partitioner)
# 0. Dig into the second stage (the one with 8 partitions)
# 0. Expand the **Event Timeline**
# 0. Notice how with 8 partitions all tests run roughly in parallel.
# 0. Notice how long it took to execute that one stage.
#   * Make note of the duration.
#   * You may want to execute it several times to get a decent average.
#
# Repeat the exercise with
# * 1 partition
# * 7 partitions
# * 9 partitions
# * 16 partitions
# * 24 partitions
# * 96 partitions
# * 200 partitions
# * 4000 partitions
#
# Go back and replace `repartition(n)` with `coalesce(n)` using:
# * 6 partitions
# * 5 partitions
# * 4 partitions
# * 3 partitions
# * 2 partitions
# * 1 partitions
#
# ** *Note:* ** *Our data isn't large enough to see big differences with small partitions.*<br/>*However, we can see the flip side of this, the effect of small data with many partitions.*

# %% [markdown]
# ##![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run "../Includes/Classroom-Setup"

# %%
parquetDir = "/mnt/training/wikipedia/pageviews/pageviews_by_second.parquet"

df = (spark.read
  .parquet(parquetDir)
  .repartition(8)
  # .coalesce(6)
)
df.count()
printRecordsPerPartition(df)

# %% [markdown]
# ## ![Spark Logo Tiny](https://files.training.databricks.com/images/105/logo_spark_tiny.png) Classroom-Cleanup<br>
#
# Run the **`Classroom-Cleanup`** cell below to remove any artifacts created by this lesson.

# %%
# %run "../Includes/Classroom-Cleanup"

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
