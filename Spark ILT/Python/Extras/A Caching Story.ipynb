# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 1200px">
# </div>

# %% [markdown]
# #Presentation Mode
# To enable presentation mode, open the JavaScript console and enter the following command:
#
# `window.settings.enablePresentationMode = true`
#
# Then from the **View** menu select **Present**

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p><p>A Caching Story<br/>featuring Tom &amp; Mary</p>
#
#     <div style="position=absolute">
#       <img src="https://files.training.databricks.com/images/working-left-man.png" style="left:0">
#       <img src="https://files.training.databricks.com/images/working-right-woman.png" style="right:0">
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>Same company &amp; the same cluster</p>
#
#     <div style="position=absolute">
#       <img src="https://files.training.databricks.com/images/working-left-man.png" style="left:0">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/working-right-woman.png" style="right:0">
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>20 GB of RAM for caching</p>
#
#     <div style="position=absolute">
#       <img src="https://files.training.databricks.com/images/working-left-man.png">
#       <img src="https://files.training.databricks.com/images/cloud.png"     style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-0.png" style="width:10%"/>
#       <img src="https://files.training.databricks.com/images/working-right-woman.png">
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>Tom uses 15 GB of the cache</p>
#
#     <div style="position=absolute">
#       <img src="https://files.training.databricks.com/images/working-left-man.png" style="left:0">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>And Tom takes a coffee break...</p>
#
#     <div style="position=absolute">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>Mary starts a job requiring 10 GB</p>
#
#     <div style="position=absolute">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#       <img src="https://files.training.databricks.com/images/working-right-woman.png" style="left:0">
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>What will happen to Mary's job?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#       <img src="https://files.training.databricks.com/images/working-right-woman.png" style="left:0">
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>What will happen to Tom's data<br/>when caching MEMORY_ONLY?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/working-left-man.png" style="left:0">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>What will happen to Tom's data<br/>when caching DISK_ONLY?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/working-left-man.png" style="left:0">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>What will happen to Tom's data<br/>when caching MEMORY_AND_DISK?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/working-left-man.png" style="left:0">
#       <img src="https://files.training.databricks.com/images/cloud.png" style="width:25%"/>
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>If the existing data is expunged,<br/>how much is expunged?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>Will Spark expunge some <br/>fraction of a partition?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>Why will Spark <b>NOT</b> expunge <br>some fraction of a partition?</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/storage-75.png" style="width:10%"/>
#       <span>+</span>
#       <img src="https://files.training.databricks.com/images/storage-50-more.png" style="width:10%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#     <p>Along comes a couple bright ideas...</p>
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%"/>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">If you are sharing a cluster, just commit to using <b>DISK_ONLY</b></p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">You should never cache data</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">You should cache data immediately after reading it</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">Fix the underlying data before looking to caching as a solution</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">Data Scientist should <b>ALWAYS</b> cache their training data</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">Analyst should only cache the final result (e.g. an aggregate)</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">Engineers should never cache data in a production job</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">Use your own cluster so that you don't have to share the cache</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# <div style="display:table; height:600px; width:100%"><div style="display:table-cell; vertical-align:middle">
#   <div style="margin: 0 auto; text-align:center; font-size:5vw">
#
#     <div style="white-space-nowrap;">
#       <img src="https://files.training.databricks.com/images/light-bulb-idea.png" style="width:25%; float:left"/>
#       <p style="text-align:left; font-size:smaller">Good Idea? / Bad Idea?</p>
#       <p style="text-align:left; margin-top:1em">Caching should have never been introduced to Apache Spark</p>
#     </div>
#
#   </div>
# </div></div>

# %% [markdown]
# -sandbox
# &copy; 2020 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
